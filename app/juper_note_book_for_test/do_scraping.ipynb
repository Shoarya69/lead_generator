# %%
from main_2_scrrapper import as_main_scrapper
import importlib

# %%
df=await as_main_scrapper()

# %%
df.head()
# Out:
#                             title  \
# 0        UK Business Advisors Ltd
# 1  UK Business Consulting Limited
# 2  Ignite Business Consultancy UK
# 3                     Growth Idea
# 4    Key Business Consultants LLP
#
#                                                 link
# 0  https://www.google.com/maps/place/UK+Business+...
# 1  https://www.google.com/maps/place/UK+Business+...
# 2  https://www.google.com/maps/place/Ignite+Busin...
# 3  https://www.google.com/maps/place/Growth+Idea/...
# 4  https://www.google.com/maps/place/Key+Business...

# %%
import pandas as pd

# %%
from use_data_in_auto import reset_all_is_used
from connect_mysql_for_123 import get_cursore as gc
# Out:
# Traceback (most recent call last):
#
#   File ~/source/web_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 1
#     from use_data_in_auto import reset_all_is_used
#
#   File ~/Desktop/leadomator/app/use_data_in_auto.py:1
#     from connect_mysql_for_123 import get_cursore as gc
#     ^
# IndentationError: unexpected indent

# %%
cursor,conn = gc()

# %%
reset_all_is_used(cursor=cursor,conn=conn)
# Out:
# All leads reset: is_used = FALSE ✅

# %%
import data_store_in_db_lead

# %%
importlib.reload(data_store_in_db_lead)
# Out:
# <module 'data_store_in_db_lead' from '/home/shoarya/Desktop/leadomator/app/data_store_in_db_lead.py'>

# %%
data_store_in_db_lead.store_data_in_db_lead_by_google_maps(query_id=1,names=df['title'],links=df['link'])
# Out:
# All set ✅ data saved in DB
